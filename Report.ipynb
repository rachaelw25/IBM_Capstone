# %% [markdown]
# # Results

# %% [markdown]
# #### The results show that there are plenty of hotels, restaurants, and music venues in Toronto for anyone considering moving there.

# %% [markdown]
# # Discussion

# %% [markdown]
# #### There could have been more data included in the report. It would have been better to base the report off of a single persons interests rather than general interest.

# %% [markdown]
# # Conclusion

# %%
##This concludes my report.
