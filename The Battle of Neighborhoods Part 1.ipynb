# %% [markdown]
# # The Battle of the Neighborhoods Part 1

# %% [markdown]
# ### To complete the data science course from IBM, I will be doing this final project. We will start by defining the data science methodology steps.

# %% [markdown]
# ## Data Science Methodology:

# %% [markdown]
# ### 1. Business Understanding
# ### 2. Analytic Approach
# ### 3. Data Requirements
# ### 4. Data Collection
# ### 5. Data Understanding
# ### 6. Data Preparation
# ### 7. Modeling
# ### 8. Deployment
# ### 9. Feedback

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# #### For this project we will be solving not a business probloem but a personal one. What would it take for you to move to a new city? What similarities to your current city and the city you are moving to have to share? For a lot of people it depends on how close you are to shopping and restaurants. Others care about music venues and parks. We will be looking at different cities in Ireland for this project.

# %% [markdown]
# ## Analytic Approach

# %% [markdown]
# #### We will need to use a descriptive approach to the data since we are showing more of a relational view of different cities.

# %% [markdown]
# ## Data Requirements & Collections

# %% [markdown]
# #### Our data will be sourced from the following url:
# #### https://en.wikipedia.org/wiki/List_of_cities,_boroughs_and_towns_in_the_Republic_of_Ireland

# %% [markdown]
# #### We then need to take this data and put it through a Python module to change the data to a Pandas dataframe.

# %% [markdown]
# ## Data Understanding & Prep

# %% [markdown]
# #### In this stage we will clean the data to make sure it is ready for the modeling stage.  We will need to attach the latitude and longitude of each city to the dataframe which we will find with Geacoder. We will also use Foursquare API to find venues and restaurants etc. in each city.

# %% [markdown]
# ### The remaining stages will be completed in the next part. As a brief overview, in the modeling stage we will make sure the data is ready and will use a descriptive model and then do a final model evaluation. We will then deploy the dataframe
